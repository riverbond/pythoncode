# %% [markdown]
# ### Making a simple plot

# %%
from matplotlib import pyplot as plt

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp   = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# %%
# add a title
plt.title("Nominal GDP")

# %%
# add a label to the y-axis
plt.ylabel("Billions of $", color="green")
plt.show()

# %% [markdown]
# ### Making a Bar Chart

# %%
movies     = ["Annie Hall", "Ben-Hur", "Casablanca", "Ghandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
# bars are by default width 0.8, so we'll add 0.1 to the left coordinates
# so that each bar is centered
xs = [i + 0.1 for i, _ in enumerate(movies)]

# %%
# plot bars with left x-coordinates [xs], heights [num_oscars]
plt.bar(xs, num_oscars)
# Out:
# <Container object of 5 artists>

# %%
plt.ylabel("# of academy awards")
plt.title("List of Movies")

# %%
# Label the x-axis with movie names at bar centers
plt.xticks([i + 0.1 for i, _ in enumerate(movies)], movies) # Book says 0.5, actually 0.1
# Out:
# ([<matplotlib.axis.XTick at 0x7fc7fe784f90>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
plt.show()

# %%
from collections import Counter

# %%
grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10 * 10

# %%
histogram = Counter(decile(grade) for grade in grades)
print histogram
# Out:
# Counter({80: 4, 70: 3, 0: 2, 90: 2, 100: 1, 60: 1})

# %%
plt.bar([x for x in histogram.keys()],      # shift each bar to the left by 4 (doesn't work!!!)
     histogram.values(),                    # give each bar its correct height
     8)                                     # give each bar a height of 8
# Out:
# <Container object of 6 artists>

# %%
plt.axis([-5, 105, 0, 5]) # x-axis -5 to 105 and y-axis 0 to 5
# Out:
# [-5, 105, 0, 5]

# %%
plt.xticks([10 * i for i in range(11)]) #x-axis labels @ 0, 10, ..., 100
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %% [markdown]
# #### Here is how misleading a bar can be when the y-axis doesn't start at zero

# %%
mentions = [500, 505]
years    = [2013, 2014]

plt.bar([2013, 2014], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone mention 'data science'")

# if you don't do this, matplotlib will label the x-axis 0, 1
# and then add a +2.013e3 off in the corner 
plt.ticklabel_format(useOffSet=False)

# misleading y-axis only shows the part above 500
plt.axis([2012.5, 2014.5, 499, 506])
plt.title("Look at the 'HUGE' increase!")
plt.show()

# %% [markdown]
# #### Using a reasonable y-axis

# %%
mentions = [500, 505]
years    = [2013, 2014]

plt.bar([2013, 2014], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone mention 'data science'")

# if you don't do this, matplotlib will label the x-axis 0, 1
# and then add a +2.013e3 off in the corner 
plt.ticklabel_format(useOffSet=False)

plt.axis([2012.5, 2014.5, 0, 550])
plt.title("Not so 'HUGE' anymore.")
plt.show()

# %% [markdown]
# #### Line Charts

# %%
variance     = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error  = [x + y for x, y in zip(variance, bias_squared)]
xs           = [i for i, _ in enumerate(variance)] 
plt.figure(figsize=(12, 10)) # MUST be set before plot calls

# %%
# multiple call to plt.plot can show multiple series on the same plot
plt.plot(xs, variance,     'g-',  label='variance')
plt.plot(xs, bias_squared, 'r-.', label='bias^2')
plt.plot(xs, total_error,  'b'  , label='total error')

# %%
# assigning labels to each series allows us a legend "free fo charge"
plt.legend(loc=9) # loc=9 means "top center"
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()
